# %%
from time import sleep
import time

from selenium import webdriver
import pandas as pd 
from bs4 import BeautifulSoup

options = webdriver.ChromeOptions()
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
#driver = webdriver.Chrome(executable_path='C:/Users/Abhishek_2/Desktop/chromedriver.exe')
#driver = webdriver.Chrome("./chromedriver")


df = pd.DataFrame(columns=["Title","Location","Company","Salary","Sponsored","Description"])

for i in range(0,1000,10):
    driver.get('https://www.indeed.co.in/jobs?q=data+science&l=India&start='+str(i))
    jobs = []
    driver.implicitly_wait(4)


    for job in driver.find_elements_by_class_name('result'):

        soup = BeautifulSoup(job.get_attribute('innerHTML'),'html.parser')

        try:
            title = soup.find("a",class_="jobtitle").text.replace("\n","").strip()

        except:
            title = 'None'

        try:
            location = soup.find(class_="location").text
        except:
            location = 'None'

        try:
            company = soup.find(class_="company").text.replace("\n","").strip()
        except:
            company = 'None'

        try:
            salary = soup.find(class_="salary").text.replace("\n","").strip()
        except:
            salary = 'None'

        try:
            sponsored = soup.find(class_="sponsoredGray").text
            sponsored = "Sponsored"
        except:
            sponsored = "Organic"

        sum_div = job.find_elements_by_class_name("summary")[0]
        try:
            sum_div.click()
        except:
            break
        job_desc = driver.find_element_by_id('vjs-desc').text

        df = df.append({'Title':title,'Location':location,"Company":company,"Salary":salary,
                        "Sponsored":sponsored,"Description":job_desc},ignore_index=True)
        time.sleep(1)
        #print("Got these many results:",df.shape)


#df.to_csv("ai.csv",index=False)
# Out:
# [WDM] - Current google-chrome version is 86.0.4240
# [WDM] - Get LATEST driver version for 86.0.4240
# [WDM] - Driver [C:\Users\Abhishek_2\.wdm\drivers\chromedriver\win32\86.0.4240.22\chromedriver.exe] found in cache
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-9-8c070b81b790> in <module>
#      58         except:
#      59             break
# ---> 60         job_desc = driver.find_element_by_id('vjs-desc').text
#      61
#      62         df = df.append({'Title':title,'Location':location,"Company":company,"Salary":salary,
#
# ~\anaconda3\envs\python3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     358             element = driver.find_element_by_id('foo')
#     359         """
# --> 360         return self.find_element(by=By.ID, value=id_)
#     361
#     362     def find_elements_by_id(self, id_):
#
# ~\anaconda3\envs\python3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\anaconda3\envs\python3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\envs\python3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="vjs-desc"]"}
#   (Session info: chrome=86.0.4240.75)

# %%
for i in range(920,1000,10):
    driver.get('https://www.indeed.co.in/jobs?q=data+science&l=India&start='+str(i))
    jobs = []
    driver.implicitly_wait(4)


    for job in driver.find_elements_by_class_name('result'):

        soup = BeautifulSoup(job.get_attribute('innerHTML'),'html.parser')

        try:
            title = soup.find("a",class_="jobtitle").text.replace("\n","").strip()

        except:
            title = 'None'

        try:
            location = soup.find(class_="location").text
        except:
            location = 'None'

        try:
            company = soup.find(class_="company").text.replace("\n","").strip()
        except:
            company = 'None'

        try:
            salary = soup.find(class_="salary").text.replace("\n","").strip()
        except:
            salary = 'None'

        try:
            sponsored = soup.find(class_="sponsoredGray").text
            sponsored = "Sponsored"
        except:
            sponsored = "Organic"

        sum_div = job.find_elements_by_class_name("summary")[0]
        try:
            sum_div.click()
        except:
            break
        job_desc = driver.find_element_by_id('vjs-desc').text

        df = df.append({'Title':title,'Location':location,"Company":company,"Salary":salary,
                        "Sponsored":sponsored,"Description":job_desc},ignore_index=True)
        time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-34-0469ceef6a31> in <module>
#      41         except:
#      42             break
# ---> 43         job_desc = driver.find_element_by_id('vjs-desc').text
#      44
#      45         df = df.append({'Title':title,'Location':location,"Company":company,"Salary":salary,
#
# ~\anaconda3\envs\python3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     358             element = driver.find_element_by_id('foo')
#     359         """
# --> 360         return self.find_element(by=By.ID, value=id_)
#     361
#     362     def find_elements_by_id(self, id_):
#
# ~\anaconda3\envs\python3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\anaconda3\envs\python3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\envs\python3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="vjs-desc"]"}
#   (Session info: chrome=86.0.4240.75)

# %%
df
# Out:
#                                                   Title  \
# 0                                Trainee - Data Science
# 1               Member Algorithm/Analytics Data Science
# 2                               Data Science Internship
# 3         Data Science part time job/internship at Pune
# 4                                 Data Science Engineer
# ...                                                 ...
# 1266  Associate Professional Business Process Outsou...
# 1267                      Analyst - Product Development
# 1268                                     "Data Analyst"
# 1269           Business Data Analyst - Bangalore, India
# 1270                    Consultant – Commercial Analyst
#
#                      Location                             Company  \
# 0      Indore, Madhya Pradesh                   Yash Technologies
# 1         Mumbai, Maharashtra       Reliance Jio Infocomm Limited
# 2     Secunderabad, Telangana      Aapoon Digital Private Limited
# 3           Pune, Maharashtra  Exa Mobility India Private Limited
# 4        Bengaluru, Karnataka                            Involvio
# ...                       ...                                 ...
# 1266     Noida, Uttar Pradesh                                 DXC
# 1267         Gurgaon, Haryana                    American Express
# 1268     Noida, Uttar Pradesh           Star Jobs Private Limited
# 1269     Bengaluru, Karnataka                    MPOWER Financing
# 1270     Bengaluru, Karnataka                                Edge
#
#                          Salary Sponsored  \
# 0                          None   Organic
# 1                          None   Organic
# 2                ₹5,000 a month   Organic
# 3     ₹10,000 - ₹20,000 a month   Organic
# 4                          None   Organic
# ...                         ...       ...
# 1266                       None   Organic
# 1267                       None   Organic
# 1268                       None   Organic
# 1269                       None   Organic
# 1270                       None   Organic
#
#                                             Description
# 0     We are looking forward to hire IT professional...
# 1     Job Responsibilities :\n\n1. Design and docume...
# 2     About the company:\nAapoon Digital Private Lim...
# 3     About the company:\nWe are a research and prod...
# 4     We are looking for a Data Scientist that will ...
# ...                                                 ...
# 1266  Job Description:\nEssential Job Functions\nCon...
# 1267  Why American Express?\nThere’s a difference be...
# 1268  â€¢Use and improve the clientâ€™s automated so...
# 1269  THE COMPANY\nMPOWER enables students from arou...
# 1270  Our global client is looking for talented and ...
#
# [1271 rows x 6 columns]

# %%
df = df.drop_duplicates()
df = df.reset_index()
df = df.drop(['index'], axis=1)
df
# Out:
#                                                  Title  \
# 0                               Trainee - Data Science
# 1              Member Algorithm/Analytics Data Science
# 2                              Data Science Internship
# 3        Data Science part time job/internship at Pune
# 4                                Data Science Engineer
# ..                                                 ...
# 884                   Senior Machine Learning Engineer
# 885             Assistant Manager - Big data developer
# 886  Associate Professional Business Process Outsou...
# 887           Business Data Analyst - Bangalore, India
# 888                    Consultant – Commercial Analyst
#
#                     Location                             Company  \
# 0     Indore, Madhya Pradesh                   Yash Technologies
# 1        Mumbai, Maharashtra       Reliance Jio Infocomm Limited
# 2    Secunderabad, Telangana      Aapoon Digital Private Limited
# 3          Pune, Maharashtra  Exa Mobility India Private Limited
# 4       Bengaluru, Karnataka                            Involvio
# ..                       ...                                 ...
# 884     Bengaluru, Karnataka                               Ushur
# 885                    India                            Vodafone
# 886     Noida, Uttar Pradesh                                 DXC
# 887     Bengaluru, Karnataka                    MPOWER Financing
# 888     Bengaluru, Karnataka                                Edge
#
#                         Salary Sponsored  \
# 0                         None   Organic
# 1                         None   Organic
# 2               ₹5,000 a month   Organic
# 3    ₹10,000 - ₹20,000 a month   Organic
# 4                         None   Organic
# ..                         ...       ...
# 884                       None   Organic
# 885                       None   Organic
# 886                       None   Organic
# 887                       None   Organic
# 888                       None   Organic
#
#                                            Description
# 0    We are looking forward to hire IT professional...
# 1    Job Responsibilities :\n\n1. Design and docume...
# 2    About the company:\nAapoon Digital Private Lim...
# 3    About the company:\nWe are a research and prod...
# 4    We are looking for a Data Scientist that will ...
# ..                                                 ...
# 884  Ushur is transforming the way businesses commu...
# 885  Skillset\nSkillset :\nBig Data Development\nSp...
# 886  Job Description:\nEssential Job Functions\nCon...
# 887  THE COMPANY\nMPOWER enables students from arou...
# 888  Our global client is looking for talented and ...
#
# [889 rows x 6 columns]

# %%
df.to_csv('indeed_ds_jd.csv')
